# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/home/wahba/Documents/nids5/test/dataset/3_Full/attack_and_benign.csv')
df2 = pd.read_csv('/home/wahba/Documents/nids5/test/dataset/2_Attack_only/Attacks.csv')
selected_features = [
    "Bwd Packet Length Std",
    "Bwd Packet Length Mean",
    "Bwd Packet Length Max",
    "Total Length of Fwd Packets",
    "Fwd Packet Length Max",
    "Fwd Packet Length Mean",
    "Fwd IAT Std",
    "Total Fwd Packets",
    "Fwd Packet Length Std",
    "Flow IAT Max",
    "Flow Bytes/s",
    "Flow IAT Std",
    "Bwd Packet Length Min",
    "Fwd IAT Total",
    "Label",
]

# Keep only the selected features
df1 = df1[selected_features]
df2 = df2[selected_features]
df2['Label'] = df2['Label'].replace('DDoS', 'DoS')

# %%
benign = df1[df1['Label'] == 'BENIGN']
attack = df1[df1['Label'] == 'Attack']

# %% [markdown]
# ## Binary Classification

# %%
features = ['Bwd Packet Length Std', 'Flow Bytes/s', 'Fwd Packet Length Std']

for feature in features:
    print(feature)
    plt.figure(figsize=(10, 5))
    # KDE for BENIGN
    sns.kdeplot(
        benign[feature], 
        label='BENIGN', 
        fill=True,      # fill under the curve
        alpha=0.4
    )

    # KDE for ATTACK
    sns.kdeplot(
        attack[feature], 
        label='ATTACK', 
        fill=True,
        alpha=0.4
    )

    plt.title(f'{feature} Distribution (KDE)')
    plt.xlabel(feature)
    plt.ylabel('Density')
    plt.legend()
    plt.show()

    sns.violinplot(data=df1, 
               x='Label', 
               y=feature,
               palette=['lightblue', 'lightcoral'])
    plt.title(f'{feature} Distribution (Violin Plot)')
    plt.ylabel(feature)
    plt.grid(axis='y', alpha=0.3)
    plt.show()
# Out:
# Bwd Packet Length Std
# /tmp/ipykernel_11237/3210369163.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df1,
# Flow Bytes/s
# /tmp/ipykernel_11237/3210369163.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df1,
# Fwd Packet Length Std
# /tmp/ipykernel_11237/3210369163.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df1,

# %%
DoS = df2[df2['Label'] == 'DoS']
Portscan = df2[df2['Label'] == 'Port Scan']
BruteForce = df2[df2['Label'] == 'Brute Force']
WebAttack = df2[df2['Label'] == 'Web Attack']
Bot = df2[df2['Label'] == 'Bot']



for feature in selected_features[:-1]:
    print(feature)
    plt.figure(figsize=(10, 5))
    # KDE for DoS
    sns.kdeplot(
        DoS[feature], 
        label='DoS', 
        fill=True,      # fill under the curve
        alpha=0.4
    )
    # KDE for Portscan
    sns.kdeplot(
        Portscan[feature], 
        label='Portscan', 
        fill=True,      # fill under the curve
        alpha=0.4
    )
    # KDE for BruteForce
    sns.kdeplot(
        BruteForce[feature], 
        label='BruteForce', 
        fill=True,      # fill under the curve
        alpha=0.4
    )
    # KDE for WebAttack
    sns.kdeplot(
        WebAttack[feature], 
        label='WebAttack', 
        fill=True,      # fill under the curve
        alpha=0.4
    )
    # KDE for Bot
    sns.kdeplot(
        Bot[feature], 
        label='Bot', 
        fill=True,      # fill under the curve
        alpha=0.4
    )

    plt.title(f'{feature} Distribution (KDE)')
    plt.xlabel(feature)
    plt.ylabel('Density')
    plt.legend()
    plt.show()



    sns.violinplot(data=df2, 
               x='Label', 
               y=feature,
               palette=['lightblue', 'lightcoral'])
    plt.title(f'{feature} Distribution (Violin Plot)')
    plt.ylabel(feature)
    plt.grid(axis='y', alpha=0.3)
    plt.show()
# Out:
# Bwd Packet Length Std
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Bwd Packet Length Mean
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Bwd Packet Length Max
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Total Length of Fwd Packets
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Fwd Packet Length Max
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Fwd Packet Length Mean
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Fwd IAT Std
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Total Fwd Packets
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Fwd Packet Length Std
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Flow IAT Max
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Flow Bytes/s
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Flow IAT Std
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Bwd Packet Length Min
# /tmp/ipykernel_11237/753906714.py:27: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /tmp/ipykernel_11237/753906714.py:34: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
# Fwd IAT Total
# /tmp/ipykernel_11237/753906714.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2,
# /tmp/ipykernel_11237/753906714.py:56: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data=df2,
