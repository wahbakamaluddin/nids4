# %%
import pandas as pd

# %%
import pandas as pd

# list of file paths
paths = [
    '/home/wahba/Documents/nids5/test/dataset/cicids2017_data_preprocessing2.csv',
    '/home/wahba/Documents/nids5/test/dataset/2_Attack_only/Attacks.csv',
    '/home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/Bot.csv',
    '/home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/Brute_Force.csv',
    '/home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/DDoS.csv',
    '/home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/DoS.csv',
    '/home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/Port_Scan.csv',
    '/home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/Web_Attack.csv'
]

for path in paths:
    print(f"Processing: {path}")
    df = pd.read_csv(path)
    
    # Drop column if exists
    if 'Destination Port' in df.columns:
        df.drop(columns='Destination Port', inplace=True)

    # Overwrite the CSV
    df.to_csv(path, index=False)

print("Done.")
# Out:
# Processing: /home/wahba/Documents/nids5/test/dataset/cicids2017_data_preprocessing2.csv
# Processing: /home/wahba/Documents/nids5/test/dataset/2_Attack_only/Attacks.csv
# Processing: /home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/Bot.csv
# Processing: /home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/Brute_Force.csv
# Processing: /home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/DDoS.csv
# Processing: /home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/DoS.csv
# Processing: /home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/Port_Scan.csv
# Processing: /home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/Web_Attack.csv
# Done.
