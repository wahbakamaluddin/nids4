# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time

# %%
seconds = time.time()

def folder(f_name): #this function creates a folder named "feaure_pics" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")
        

# CSV files names:
csv_files = [f for f in os.listdir("/home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/") if f.endswith(".csv")]

# Headers of column
main_labels = ["Flow Duration","Total Fwd Packets","Total Length of Fwd Packets","Fwd Packet Length Max",
               "Fwd Packet Length Min","Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max",
               "Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std","Flow Bytes/s","Flow Packets/s",
               "Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std",
               "Fwd IAT Max","Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min",
               "Fwd PSH Flags","Fwd URG Flags","Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s",
               "Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std","Packet Length Variance",
               "FIN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","ECE Flag Count",
               "Down/Up Ratio","Average Packet Size","Subflow Fwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward",
               "act_data_pkt_fwd","min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min","Idle Mean","Idle Std","Idle Max","Idle Min","Label"]

ths = open("importance_list_for_attack_files.csv", "w")
folder("./feaure_pics/")
for j in csv_files:
    df=pd.read_csv("/home/wahba/Documents/nids5/test/dataset/1_Attacks_70_30/"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)           
    df["Label"]=attack_or_not

    y = df["Label"].values
    del df["Label"]
    X = df.values
    
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0
   

    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances  
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break     
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("./feaure_pics/"+j[0:-4]+".pdf",bbox_inches='tight', format = 'pdf')
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Brute_Force importance list:
# Brute_Force
#                               importance
# Features
# Fwd Packet Length Max          0.019254
# Total Length of Fwd Packets    0.014921
# Bwd Packet Length Mean         0.005017
# Flow IAT Max                   0.001769
# Flow Bytes/s                   0.000803
# Fwd IAT Mean                   0.000786
# Fwd IAT Total                  0.000703
# Flow Duration                  0.000695
# Flow IAT Mean                  0.000603
# Fwd Packet Length Mean         0.000579
# Flow Packets/s                 0.000549
# Fwd IAT Std                    0.000432
# Flow IAT Std                   0.000421
# Bwd Packet Length Std          0.000285
# Total Fwd Packets              0.000223
# Bwd Packet Length Max          0.000115
# Fwd Packet Length Std          0.000108
# Flow IAT Min                   0.000106
# Fwd Packet Length Min          0.000010
# Bwd Packet Length Min          0.000006
#
#
#
# Brute_Force=["Fwd Packet Length Max","Total Length of Fwd Packets","Bwd Packet Length Mean","Flow IAT Max","Flow Bytes/s"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Bwd Packet Length Std          0.543719
# Total Length of Fwd Packets    0.007007
# Fwd Packet Length Max          0.001602
# Bwd Packet Length Min          0.000272
# Fwd Packet Length Std          0.000217
# Bwd Packet Length Mean         0.000105
# Bwd Packet Length Max          0.000092
# Flow IAT Min                   0.000087
# Flow Bytes/s                   0.000065
# Flow Duration                  0.000061
# Flow IAT Std                   0.000056
# Fwd IAT Total                  0.000048
# Flow IAT Max                   0.000035
# Fwd IAT Std                    0.000033
# Flow Packets/s                 0.000032
# Fwd IAT Mean                   0.000031
# Flow IAT Mean                  0.000029
# Fwd Packet Length Min          0.000029
# Fwd Packet Length Mean         0.000018
# Total Fwd Packets              0.000004
#
#
#
# DDoS=["Bwd Packet Length Std","Total Length of Fwd Packets","Fwd Packet Length Max","Bwd Packet Length Min","Fwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Bot importance list:
# Bot
#                               importance
# Features
# Bwd Packet Length Mean         0.706606
# Flow IAT Min                   0.016684
# Flow IAT Max                   0.014228
# Fwd IAT Std                    0.011248
# Flow IAT Std                   0.008008
# Flow IAT Mean                  0.004271
# Flow Duration                  0.002747
# Flow Packets/s                 0.001336
# Flow Bytes/s                   0.001307
# Bwd Packet Length Max          0.000518
# Total Length of Fwd Packets    0.000273
# Fwd Packet Length Mean         0.000263
# Bwd Packet Length Std          0.000178
# Fwd Packet Length Max          0.000163
# Fwd Packet Length Std          0.000154
# Fwd IAT Total                  0.000151
# Fwd IAT Mean                   0.000130
# Total Fwd Packets              0.000096
# Fwd Packet Length Min          0.000034
# Bwd Packet Length Min          0.000017
#
#
#
# Bot=["Bwd Packet Length Mean","Flow IAT Min","Flow IAT Max","Fwd IAT Std","Flow IAT Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS importance list:
# DoS
#                               importance
# Features
# Bwd Packet Length Std          0.778587
# Fwd IAT Total                  0.022000
# Flow IAT Std                   0.013456
# Bwd Packet Length Mean         0.009289
# Fwd IAT Mean                   0.004539
# Flow IAT Min                   0.002631
# Fwd IAT Std                    0.001498
# Fwd Packet Length Max          0.001237
# Flow Bytes/s                   0.001223
# Flow IAT Mean                  0.001158
# Fwd Packet Length Std          0.000910
# Flow Packets/s                 0.000676
# Bwd Packet Length Max          0.000636
# Flow Duration                  0.000482
# Fwd Packet Length Min          0.000355
# Fwd Packet Length Mean         0.000341
# Total Length of Fwd Packets    0.000317
# Flow IAT Max                   0.000316
# Total Fwd Packets              0.000270
# Bwd Packet Length Min          0.000040
#
#
#
# DoS=["Bwd Packet Length Std","Fwd IAT Total","Flow IAT Std","Bwd Packet Length Mean","Fwd IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web_Attack importance list:
# Web_Attack
#                               importance
# Features
# Total Length of Fwd Packets    0.024382
# Flow Bytes/s                   0.005011
# Bwd Packet Length Std          0.002819
# Fwd Packet Length Mean         0.001939
# Flow IAT Max                   0.001937
# Bwd Packet Length Max          0.001884
# Flow IAT Mean                  0.001296
# Flow IAT Min                   0.001189
# Flow Duration                  0.001104
# Flow Packets/s                 0.000982
# Fwd IAT Total                  0.000487
# Bwd Packet Length Mean         0.000426
# Fwd Packet Length Std          0.000383
# Fwd Packet Length Max          0.000307
# Fwd IAT Mean                   0.000244
# Total Fwd Packets              0.000148
# Fwd IAT Std                    0.000130
# Flow IAT Std                   0.000084
# Bwd Packet Length Min          0.000000
# Fwd Packet Length Min          0.000000
#
#
#
# Web_Attack=["Total Length of Fwd Packets","Flow Bytes/s","Bwd Packet Length Std","Fwd Packet Length Mean","Flow IAT Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Port_Scan importance list:
# Port_Scan
#                               importance
# Features
# Flow Bytes/s                   0.312821
# Total Length of Fwd Packets    0.297870
# Flow Duration                  0.001943
# Fwd IAT Total                  0.001683
# Bwd Packet Length Std          0.000751
# Fwd IAT Mean                   0.000649
# Flow IAT Max                   0.000641
# Flow IAT Mean                  0.000169
# Fwd Packet Length Max          0.000138
# Total Fwd Packets              0.000129
# Flow IAT Min                   0.000104
# Flow IAT Std                   0.000094
# Fwd Packet Length Std          0.000084
# Flow Packets/s                 0.000074
# Fwd IAT Std                    0.000052
# Fwd Packet Length Mean         0.000049
# Bwd Packet Length Mean         0.000013
# Bwd Packet Length Max          0.000011
# Fwd Packet Length Min          0.000008
# Bwd Packet Length Min          0.000003
#
#
#
# Port_Scan=["Flow Bytes/s","Total Length of Fwd Packets","Flow Duration","Fwd IAT Total","Bwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  8238.705106019974 seconds
