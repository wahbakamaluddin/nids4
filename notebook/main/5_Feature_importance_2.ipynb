# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time

# %%
import os
import time
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

seconds = time.time()

def folder(f_name):
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print("The folder could not be created!")


# CSV files:
csv_files = [f for f in os.listdir("/home/wahba/Documents/nids5/test/dataset/3_Full/") if f.endswith(".csv")]

# Headers
main_labels = ["Flow Duration","Total Fwd Packets","Total Length of Fwd Packets","Fwd Packet Length Max",
               "Fwd Packet Length Min","Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max",
               "Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std","Flow Bytes/s","Flow Packets/s",
               "Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std",
               "Fwd IAT Max","Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min",
               "Fwd PSH Flags","Fwd URG Flags","Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s",
               "Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std","Packet Length Variance",
               "FIN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","ECE Flag Count",
               "Down/Up Ratio","Average Packet Size","Subflow Fwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward",
               "act_data_pkt_fwd","min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min","Idle Mean","Idle Std","Idle Max","Idle Min","Label"]

folder("./feaure_pics/")

for j in csv_files:

    # Load CSV
    df = pd.read_csv("/home/wahba/Documents/nids5/test/dataset/3_Full/" + j, usecols=main_labels)
    df = df.fillna(0)

    # --- KEEP ORIGINAL ATTACK LABELS (no BENIGN conversion!) ---
    y = df["Label"].values
    del df["Label"]

    X = df.values
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0

    # --- RandomForestClassifier (multi-class attack classification) ---
    forest = RandomForestClassifier(n_estimators=250, random_state=0, n_jobs=-1)
    forest.fit(X, y)

    importances = forest.feature_importances_
    indices = np.argsort(importances)[::-1]

    ref_cols = list(df.columns.values)

    impor_bars = pd.DataFrame({
        'Features': ref_cols[0:20],
        'importance': importances[0:20]
    })

    impor_bars = impor_bars.sort_values('importance', ascending=False).set_index('Features')

    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar()

    # Printing top 5 features as text
    count = 0
    fea_ture = j[0:-4] + "=["
    for i in impor_bars.index:
        fea_ture += "\"" + str(i) + "\","
        count += 1
        if count == 5:
            fea_ture = fea_ture[0:-1] + "]"
            break

    print(j[0:-4], "importance list:")
    print(j[0:-4], "\n", impor_bars.head(20), "\n\n\n")
    print(fea_ture)

    plt.title(j[0:-4] + " - Attack Type Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("./feaure_pics/" + j[0:-4] + ".pdf", bbox_inches='tight', format='pdf')
    plt.tight_layout()
    plt.show()

    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

print("mission accomplished!")
print("Total operation time: = ", time.time() - seconds, "seconds")
# Out:
# cicids2017_data_preprocessing2 importance list:
# cicids2017_data_preprocessing2
#                               importance
# Features
# Bwd Packet Length Std          0.063065
# Bwd Packet Length Mean         0.056568
# Bwd Packet Length Max          0.045766
# Total Length of Fwd Packets    0.044423
# Fwd Packet Length Max          0.031184
# Fwd Packet Length Mean         0.025451
# Fwd IAT Std                    0.021565
# Total Fwd Packets              0.021154
# Fwd Packet Length Std          0.020918
# Flow IAT Max                   0.017440
# Flow Bytes/s                   0.012856
# Flow IAT Std                   0.011869
# Bwd Packet Length Min          0.011008
# Fwd IAT Total                  0.010816
# Fwd IAT Mean                   0.009843
# Flow IAT Mean                  0.009756
# Flow Packets/s                 0.008902
# Flow Duration                  0.008740
# Fwd Packet Length Min          0.004187
# Flow IAT Min                   0.003841
#
#
#
# cicids2017_data_preprocessing2=["Bwd Packet Length Std","Bwd Packet Length Mean","Bwd Packet Length Max","Total Length of Fwd Packets","Fwd Packet Length Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  850.9274072647095 seconds
