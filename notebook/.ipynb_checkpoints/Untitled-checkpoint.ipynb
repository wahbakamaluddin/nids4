# %%
import os

for root, dirs, files in os.walk("/Users/wahba/Documents/github/nids2/", topdown=False):
    print(root, dirs, files)
    print("\n")
# Out:
# /Users/wahba/Documents/github/nids2/python/.ipynb_checkpoints [] ['gui-checkpoint.py']
#
#
# /Users/wahba/Documents/github/nids2/python ['.ipynb_checkpoints'] ['tkintertest.py', 'nids.py', 'ids_chatgpt_revise.py', 'gui.py']
#
#
# /Users/wahba/Documents/github/nids2/dataset/cleaned_self [] []
#
#
# /Users/wahba/Documents/github/nids2/dataset/cleaned_kaggle [] ['cicids2017_cleaned.csv']
#
#
# /Users/wahba/Documents/github/nids2/dataset/raw/.ipynb_checkpoints [] []
#
#
# /Users/wahba/Documents/github/nids2/dataset/raw ['.ipynb_checkpoints'] ['Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv', '.DS_Store', 'Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Tuesday-WorkingHours.pcap_ISCX.csv', 'Wednesday-workingHours.pcap_ISCX.csv', 'Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv']
#
#
# ...
